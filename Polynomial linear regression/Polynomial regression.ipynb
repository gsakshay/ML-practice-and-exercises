# %% [markdown]
# ## Polynomial regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("Position_Salaries.csv")
X = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# ### Training linear regression model

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# ### Training ploynomial regression model

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_regressor = PolynomialFeatures(degree=4)
X_poly = poly_regressor.fit_transform(X)
regressor_2 = LinearRegression()
regressor_2.fit(X_poly, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# ### Visualising linear regression model

# %%
fig, (ax0, ax1) = plt.subplots(ncols=2, figsize = (15,6))
ax0.scatter(X, y, color = "red")
ax0.plot(X, regressor.predict(X), color = "blue")
ax0.set(title = "Truth or bluff (Linear regression)", 
        xlabel = "Position level", 
        ylabel = "salary")
ax1.scatter(X, y, color = "red")
ax1.plot(X, regressor_2.predict(X_poly), color = "blue")
ax1.set(title = "Truth or bluff (Polynomial regression)", 
        xlabel = "Position level", 
        ylabel = "salary");

# %%
regressor.predict([[6.5]])
# Out:
# array([330378.78787879])

# %%
regressor_2.predict(poly_regressor.fit_transform([[6.5]]))
# Out:
# array([158862.45265153])
